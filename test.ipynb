# %%
import pandas as pd

# Load the pickle file (assumes it contains a DataFrame)
df = pd.read_pickle("/Users/prashantronad/Documents/College/6thsem/IDP/Alsnet/y_test.pkl")

# Save it as CSV
df.to_csv("output_file_test_y.csv", index=False)


print("Conversion complete: input_file.pkl → output_file.csv")
# Out:
# Conversion complete: input_file.pkl → output_file.csv

# %%
import pandas as pd
x = pd.read_csv('output_file_test.csv')
print(x[0:1000])
# Out:
#               0           1           2           3           4           5  \
# 0    -20.447089  -18.997482  -18.997482  -16.937514  -17.929351  -17.318990
# 1     88.883803   98.954757  105.745022  109.712367  114.366369  116.044862
# 2     40.817884   43.717098   39.215686   38.376440   39.063096   38.300145
# 3     79.423209   68.513008   71.412222   61.493858   58.823529   54.932479
# 4     11.596857   11.978332    9.155413    9.079118   13.427939   11.520562
# ..          ...         ...         ...         ...         ...         ...
# 660  -39.597162  -35.858701  -35.324636  -31.204700  -36.011292  -37.537194
# 661   15.640497   21.744106   18.921187   20.447089   19.073777   17.929351
# 662  -61.341268  -59.967956  -62.867170  -63.172351  -63.096056  -61.264973
# 663  -36.469062  -34.790570  -31.815061  -34.180209  -32.883192  -32.578012
# 664  333.409628  333.562219  336.919203  338.979171  335.774777  333.714809
#
# ...
